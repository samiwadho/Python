# %%
            # A Smarter Way to Learn Python / Chapter 11 else and elif statements

#Q1 
if species == "cat":
 print("Yep, it's cat.")
__________
print("Nope, not cat.")
#Answer
else:
    
#Q2 If the condition tested in line 1 fails, 
#line 3 tests for a different condition. What keyword goes in the blank?
 if donut_condition == "fresh":
   buy_score = 10
 ____ donut_price == "low":
   buy_score = 5
 else:
   buy_score = 0
#Answer
elif

#Q3 Code the next line that says what to do if the test fails.
if a == b:
   print("a equals b")
#Answer
else:
    
#Q4 Code the next line. If a doesn't equal b, test whether c equals d.
if a == b:
   print("a equals b")
#Answer
elif c == d:

#Q5 Code four lines. If a equals b, c equals d. If the test fails, e equals f.
#Answer.
if a == b:
  c = d
else:
  e = f

#Q6 Code four lines. If a equals b, c equals d. 
#If that test fails, then if e equals f, g equals h.
#Answer
if a == b:
    c = d
    elif e == f :
        g = h

#Q7What is the value of x?
if 2 + 3 == 4:
  x = 0
elif 2 - 1 == 1:
  x = 1
elif 3 + 3 == 6:
  x = 2
else:
  x = 3
#Answer
1

#Q8 Code the next two lines. If the test fails, test if a equals 2. 
#If so, display "a equals 2".
if a == 1:
  print("a equals 1")
#Answer
elif a == 2:
print ("a equals 2")

#Q9Code the next two lines. If the first two tests fail, display "failed".
if a == b:
  print("ok")
elif c == d:
  print("ok")
#Answer
else :
print ("failed")

#Q10 Code six lines. If a equals b, display "ok". If not, then if c equals d, display "ok".
    #If both tests fail, display "failed".
#Answer
if a == b : 
print ("ok")
elif c == d :
print ("ok")
else :
print ("failed")

#Q11 Display wrong if the condition isn't met.
#Click the Run button    above your code. 
#If you've coded correctly, wrong will display in the right-hand panel.
#(You can click Instructions at the top of the right-hand panel to see the correct code.)

#Answer
if "dog" == "cat":
  print ("That's crazy")
# On the next two lines, display "wrong" if the condition isn't met.
else :
  print ("wrong")

#Q12 If the first condition isn't met, test whether "cat" equals "cat." If so display ok
#Click the Run button    above your code. 
#If you've coded correctly, ok will display in the right-hand panel.
#(You can click Instructions at the top of the right-hand panel to see the correct code.)
#Answer
if "dog" == "cat":
  proposition = "crazy"
# On the next two lines, if the condition above isn't met,
# test whether "cat" is equal to "cat"
# If so, display "ok"
elif "cat" == "cat"  :
    print ("ok")
