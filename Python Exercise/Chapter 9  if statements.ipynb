# %%
            # A Smarter Way to Learn Python / Chapter 9 if statements
    
#Q1 Rewrite this line so it's valid:
    if species = "cat":
#Answer 
if species == "cat" :

    
#Q2 Rewrite this line so it's valid:
if species == "cat"
#Answer
if species == "cat":
    
#Q3  Write the first line of an if statement that tests whether species is "cat"
#Answer
if species == "cat":

#Q4 Code the first line of an if statement that tests whether x has the same value as y
#Answer
if x == y:

#Q5 Code the first line of an if statement that 
#tests whether one variable is the same as another. Make up the variable names.
#Answer
if name == Sami:
    
#Q6 Below, I've coded the first line of an if statement. Code the second line.
#The second line tells Python to display the string "OK". Don't forget to indent the second line.
if current_address == previous_address:
#Answer
print("OK")

#Q7 On line 1, test whether a has the same value as b. On line 2, 
    #write that c equals d. Don't forget to indent the second line.
#Answer
if a == b :
c = d


#Q8 If total has the value of 100, tax has the value of 2. 
    #Code both lines. Don't forget to indent the second line.
#Answer
if total == 100:
 tax = 2

#Q9 If first_name is "Sherlock" last_name is "Holmes" and pal is "Watson". Code all three lines.
#Answer
if first_name == "Sherlock":
last_name = "Holmes "
pal ="Watson"

#Q10 If you_won is "yes" tell Python to display "congrats". Code both lines.
#Answer
if you_won == "yes":
 print("Congrats")

#Q11     Correct the mistakes on line 2.
    #1 Click the Run button   above your code. 
    #2 If you've coded correctly, correct will display in the right-hand panel. 
    #(You can click Instructions at the top of the right-hand panel to see the correct code.)
#Answer
species = "human"
if species == "human":
  print("correct")

#Q12    1 Test if 2 equals 2. If it does, display ok
    #2 Click the Run button   above your code. If you've coded correctly, the ok will display in the right-hand panel. 
    #(You can click Instructions at the top of the right-hand panel to see the correct code.)
#Answer
if 2 == 2:
  print ("ok")
